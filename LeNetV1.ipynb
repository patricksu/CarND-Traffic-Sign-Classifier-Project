# %% [markdown]
# # LeNet for Traffic Sign V1
# ![LeNet Architecture](lenet.png)
# Modified from source: Yan LeCun
#
# Author: Peng "Patrick" Su

# %% [markdown]
# ## Load Data
#
# Load the traffic sign data

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import tensorflow as tf
import cv2
# %matplotlib inline

# %%
# Load pickled data
import pickle

# TODO: Fill this in based on where you saved the training and testing data

training_file = '../traffic-signs-data/train.p'
validation_file = '../traffic-signs-data/valid.p'
testing_file = '../traffic-signs-data/test.p'

with open(training_file, mode='rb') as f:
    train = pickle.load(f)
with open(validation_file, mode='rb') as f:
    valid = pickle.load(f)
with open(testing_file, mode='rb') as f:
    test = pickle.load(f)
    
X_train, y_train = train['features'], train['labels']
X_valid, y_valid = valid['features'], valid['labels']
X_test, y_test = test['features'], test['labels']

# %% [markdown]
# The traffic sign data comes as 32x32x3 images, and LeNet accepts 32x32xC images. No need to pad anything.

# %% [markdown]
# ## Preprocess Data
#
# Shuffle the training data.
#
# You do not need to modify this section.

# %%
from sklearn.utils import shuffle

X_train, y_train = shuffle(X_train, y_train)

# %%
def normalize(img):
    return (img - 128.)/128.
def gray(img):
    if len(img.shape) > 3:
        ans = []
        for ig in img:
            ans.append(cv2.cvtColor(ig, cv2.COLOR_RGB2GRAY))
        return np.array(ans)
    else:
        return cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)

X_train = gray(X_train)
X_train = normalize(X_train)
X_train = X_train.astype('float32')
X_train = np.expand_dims(X_train, 3)

X_valid = gray(X_valid)
X_valid = normalize(X_valid)
X_valid = X_valid.astype('float32')
X_valid = np.expand_dims(X_valid, 3)

X_test = gray(X_test)
X_test = normalize(X_test)
X_test = X_test.astype('float32')
X_test = np.expand_dims(X_test, 3)

# %%
X_train.shape
# Out:
# (34799, 32, 32, 1)

# %%
X_train.dtype
# Out:
# dtype('float32')

# %% [markdown]
# ## Setup TensorFlow
# The `EPOCH` and `BATCH_SIZE` values affect the training speed and model accuracy.
#
# You do not need to modify this section.

# %%
import tensorflow as tf

# %% [markdown]
# ## TODO: Implement LeNet-5
# Implement the [LeNet-5](http://yann.lecun.com/exdb/lenet/) neural network architecture.
#
# This is the only cell you need to edit.
# ### Input
# The LeNet architecture accepts a 32x32xC image as input, where C is the number of color channels. Since MNIST images are grayscale, C is 1 in this case.
#
# ### Architecture
# **Layer 1: Convolutional.** The output shape should be 28x28x6.
#
# **Activation.** Your choice of activation function.
#
# **Pooling.** The output shape should be 14x14x6.
#
# **Layer 2: Convolutional.** The output shape should be 10x10x16.
#
# **Activation.** Your choice of activation function.
#
# **Pooling.** The output shape should be 5x5x16.
#
# **Flatten.** Flatten the output shape of the final pooling layer such that it's 1D instead of 3D. The easiest way to do is by using `tf.contrib.layers.flatten`, which is already imported for you.
#
# **Layer 3: Fully Connected.** This should have 120 outputs.
#
# **Activation.** Your choice of activation function.
#
# **Layer 4: Fully Connected.** This should have 84 outputs.
#
# **Activation.** Your choice of activation function.
#
# **Layer 5: Fully Connected (Logits).** This should have 10 outputs.
#
# ### Output
# Return the result of the 2nd fully connected layer.

# %%
from tensorflow.contrib.layers import flatten

def LeNet(x):    
    # Arguments used for tf.truncated_normal, randomly defines variables for the weights and biases for each layer
    mu = 0
    sigma = 0.1
    weights = {
        'wc1': tf.Variable(tf.truncated_normal([5,5,1,6], mu, sigma)),
        'wc2': tf.Variable(tf.truncated_normal([5,5,6,16], mu, sigma)),
        'wf3': tf.Variable(tf.truncated_normal([5*5*16, 120], mu, sigma)),
        'wf4': tf.Variable(tf.truncated_normal([120, 84], mu, sigma)),
        'wf5': tf.Variable(tf.truncated_normal([84, 43], mu, sigma))}
    biases = {
        'bc1': tf.zeros([6]),
        'bc2': tf.zeros([16]),
        'bf3': tf.zeros([120]),
        'bf4': tf.zeros([84]),
        'bf5': tf.zeros([43]),
    }
    # TODO: Layer 1: Convolutional. Input = 32x32x1. Output = 28x28x6.
    conv1 = tf.nn.conv2d(x, weights['wc1'], strides = [1, 1, 1, 1], padding = 'VALID')
    conv1 = tf.nn.bias_add(conv1, biases['bc1'])
    # TODO: Activation.
    conv1 = tf.nn.relu(conv1)    
    # TODO: Pooling. Input = 28x28x6. Output = 14x14x6.
    conv1 = tf.nn.max_pool(conv1, ksize = [1, 2, 2, 1], strides = [1, 2, 2, 1], padding = 'VALID')
    conv1 = tf.nn.dropout(conv1, keep_prob)
#     flat1 = flatten(conv1, [-1, 14*14*6])
    
    # TODO: Layer 2: Convolutional. Output = 10x10x16.
    conv2 = tf.nn.conv2d(conv1, weights['wc2'], strides = [1, 1, 1, 1], padding = 'VALID')
    conv2 = tf.nn.bias_add(conv2, biases['bc2'])    
    # TODO: Activation.
    conv2 = tf.nn.relu(conv2)
    # TODO: Pooling. Input = 10x10x16. Output = 5x5x16.
    conv2 = tf.nn.max_pool(conv2, ksize = [1, 2, 2, 1], strides = [1, 2, 2, 1], padding = 'VALID')
    conv2 = tf.nn.dropout(conv2, keep_prob)
    # TODO: Flatten. Input = 5x5x8. Output = 200.

#     flat2 = flatten(conv2, [-1, 5*5*16])
#     flat = tf.concat(1, [flat1, flat2])
    
    flat = flatten(conv2, [-1, 5*5*16])
    
    # TODO: Layer 3: Fully Connected. Input = 400. Output = 120.
    fc3 = tf.add(tf.matmul(flat, weights['wf3']), biases['bf3'])
    # TODO: Activation.
    fc3 = tf.nn.relu(fc3)
    # TODO: Layer 4: Fully Connected. Input = 120. Output = 84.
    fc4 = tf.add(tf.matmul(fc3, weights['wf4']), biases['bf4'])
    # TODO: Activation.
    fc4 = tf.nn.relu(fc4)
    # TODO: Layer 5: Fully Connected. Input = 84. Output = 43.
    logits = tf.add(tf.matmul(fc4, weights['wf5']), biases['bf5'])
    
    return logits

# %% [markdown]
# ## Features and Labels
# Train LeNet to classify traffic sign data.
#
# `x` is a placeholder for a batch of input images.
# `y` is a placeholder for a batch of output labels.
#
# You do not need to modify this section.

# %%
x = tf.placeholder(tf.float32, (None, 32, 32, 1))
y = tf.placeholder(tf.int32, (None))
one_hot_y = tf.one_hot(y, 43)
keep_prob = tf.placeholder(tf.float32)

# %% [markdown]
# ## Training Pipeline
# Create a training pipeline that uses the model to classify MNIST data.
#
# You do not need to modify this section.

# %%
rate = 0.001
logits = LeNet(x)
correct_prediction = tf.equal(tf.argmax(logits, 1), tf.argmax(one_hot_y, 1))
accuracy_operation = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))
cross_entropy = tf.nn.softmax_cross_entropy_with_logits(labels=one_hot_y, logits=logits)
loss_operation = tf.reduce_mean(cross_entropy)
optimizer = tf.train.AdamOptimizer(learning_rate = rate)
training_operation = optimizer.minimize(loss_operation)

# %% [markdown]
# ## Model Evaluation
# Evaluate how well the loss and accuracy of the model for a given dataset.
#
# You do not need to modify this section.

# %%
saver = tf.train.Saver(max_to_keep=100)

def evaluate(X_data, y_data):
    num_examples = len(X_data)
    total_accuracy = 0
    total_loss = 0
    sess = tf.get_default_session()
    for offset in range(0, num_examples, BATCH_SIZE):
        batch_x, batch_y = X_data[offset:offset+BATCH_SIZE], y_data[offset:offset+BATCH_SIZE]
        loss, accuracy = sess.run([loss_operation, accuracy_operation], feed_dict={x: batch_x, y: batch_y, keep_prob:1.0})
        total_accuracy += (accuracy * len(batch_x))
        total_loss += (loss * len(batch_x))
    return total_loss / num_examples, total_accuracy / num_examples

# %% [markdown]
# ## Train the Model
# Run the training data through the training pipeline to train the model.
#
# Before each epoch, shuffle the training set.
#
# After each epoch, measure the loss and accuracy of the validation set.
#
# Save the model after training.
#
# You do not need to modify this section.

# %%
import shutil
save_dir = 'LeNetV1'
out_dir = out_dir = os.path.abspath(os.path.join(os.path.curdir, "../Traffic-Sign-Classifier-runs", save_dir))
if os.path.exists(out_dir):
    shutil.rmtree(out_dir)
train_summary_dir = os.path.join(out_dir, "train")        
valid_summary_dir = os.path.join(out_dir, "valid")
checkpoint_dir = os.path.join(out_dir, "checkpoints")
if not os.path.exists(checkpoint_dir):
    os.makedirs(checkpoint_dir)
checkpoint_prefix = os.path.join(checkpoint_dir,"model")
checkpoint_every = 100
train_summary_every = 100
valid_summary_every = 100

EPOCHS = 40
BATCH_SIZE = 128

with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    num_examples = len(X_train)
    
    print("Training...")
    print()
    global_step = 0
    train_summary_writer = tf.summary.FileWriter(train_summary_dir, sess.graph)
    valid_summary_writer = tf.summary.FileWriter(valid_summary_dir, sess.graph)
    for i in range(EPOCHS):
        X_train, y_train = shuffle(X_train, y_train)
        for offset in range(0, num_examples, BATCH_SIZE):
            end = offset + BATCH_SIZE
            batch_x, batch_y = X_train[offset:end], y_train[offset:end]
            sess.run(training_operation, feed_dict={x: batch_x, y: batch_y, keep_prob:0.8})
            global_step += 1
            if global_step % train_summary_every == 0:
                train_loss, train_accuracy = evaluate(batch_x, batch_y)
                train_summaries = tf.Summary()
                train_summaries.value.add(tag='Train Loss', simple_value=train_loss)
                train_summaries.value.add(tag='Train Accuracy', simple_value=train_accuracy)
                train_summary_writer.add_summary(train_summaries, global_step)
                print("Batch {} Train Loss: {:.3f} Train Accuracy: {:.3f}".format(global_step, train_loss, train_accuracy))
                print()
            if global_step % valid_summary_every == 0:
                validation_loss, validation_accuracy = evaluate(X_valid, y_valid)
                valid_summaries = tf.Summary()
                valid_summaries.value.add(tag='Validation Loss', simple_value=validation_loss)
                valid_summaries.value.add(tag='Validation Accuracy', simple_value=validation_accuracy)
                print("valid writing")
                valid_summary_writer.add_summary(valid_summaries, global_step)
                print("EPOCH {} Batch {} ...".format(i+1, global_step))
                print("Validation loss = {:.3f}".format(validation_loss))
                print("Validation Accuracy = {:.3f}".format(validation_accuracy))
                print()
            if global_step % checkpoint_every == 0:
                saver.save(sess, checkpoint_prefix, global_step=global_step)            
    print("Training Done")
# Out:
# Training...
#
# Batch 100 Train Loss: 2.869 Train Accuracy: 0.281
#
# valid writing
# EPOCH 1 Batch 100 ...
# Validation loss = 3.122
# Validation Accuracy = 0.226
#
# Batch 200 Train Loss: 1.352 Train Accuracy: 0.648
#
# valid writing
# EPOCH 1 Batch 200 ...
# Validation loss = 1.501
# Validation Accuracy = 0.578
#
# Batch 300 Train Loss: 0.699 Train Accuracy: 0.867
#
# valid writing
# EPOCH 2 Batch 300 ...
# Validation loss = 1.001
# Validation Accuracy = 0.721
#
# Batch 400 Train Loss: 0.583 Train Accuracy: 0.797
#
# valid writing
# EPOCH 2 Batch 400 ...
# Validation loss = 0.732
# Validation Accuracy = 0.798
#
# Batch 500 Train Loss: 0.435 Train Accuracy: 0.930
#
# valid writing
# EPOCH 2 Batch 500 ...
# Validation loss = 0.605
# Validation Accuracy = 0.838
#
# Batch 600 Train Loss: 0.292 Train Accuracy: 0.961
#
# valid writing
# EPOCH 3 Batch 600 ...
# Validation loss = 0.518
# Validation Accuracy = 0.863
#
# Batch 700 Train Loss: 0.229 Train Accuracy: 0.945
#
# valid writing
# EPOCH 3 Batch 700 ...
# Validation loss = 0.496
# Validation Accuracy = 0.881
#
# Batch 800 Train Loss: 0.167 Train Accuracy: 0.961
#
# valid writing
# EPOCH 3 Batch 800 ...
# Validation loss = 0.435
# Validation Accuracy = 0.871
#
# Batch 900 Train Loss: 0.342 Train Accuracy: 0.906
#
# valid writing
# EPOCH 4 Batch 900 ...
# Validation loss = 0.413
# Validation Accuracy = 0.894
#
# Batch 1000 Train Loss: 0.192 Train Accuracy: 0.938
#
# valid writing
# EPOCH 4 Batch 1000 ...
# Validation loss = 0.396
# Validation Accuracy = 0.886
#
# Batch 1100 Train Loss: 0.126 Train Accuracy: 0.984
#
# valid writing
# EPOCH 5 Batch 1100 ...
# Validation loss = 0.397
# Validation Accuracy = 0.906
#
# Batch 1200 Train Loss: 0.150 Train Accuracy: 0.977
#
# valid writing
# EPOCH 5 Batch 1200 ...
# Validation loss = 0.386
# Validation Accuracy = 0.896
#
# Batch 1300 Train Loss: 0.183 Train Accuracy: 0.961
#
# valid writing
# EPOCH 5 Batch 1300 ...
# Validation loss = 0.325
# Validation Accuracy = 0.911
#
# Batch 1400 Train Loss: 0.180 Train Accuracy: 0.961
#
# valid writing
# EPOCH 6 Batch 1400 ...
# Validation loss = 0.312
# Validation Accuracy = 0.924
#
# Batch 1500 Train Loss: 0.204 Train Accuracy: 0.945
#
# valid writing
# EPOCH 6 Batch 1500 ...
# Validation loss = 0.351
# Validation Accuracy = 0.906
#
# Batch 1600 Train Loss: 0.069 Train Accuracy: 0.992
#
# valid writing
# EPOCH 6 Batch 1600 ...
# Validation loss = 0.357
# Validation Accuracy = 0.913
#
# Batch 1700 Train Loss: 0.090 Train Accuracy: 0.984
#
# valid writing
# EPOCH 7 Batch 1700 ...
# Validation loss = 0.285
# Validation Accuracy = 0.923
#
# Batch 1800 Train Loss: 0.072 Train Accuracy: 0.984
#
# valid writing
# EPOCH 7 Batch 1800 ...
# Validation loss = 0.328
# Validation Accuracy = 0.915
#
# Batch 1900 Train Loss: 0.036 Train Accuracy: 1.000
#
# valid writing
# EPOCH 7 Batch 1900 ...
# Validation loss = 0.300
# Validation Accuracy = 0.918
#
# Batch 2000 Train Loss: 0.047 Train Accuracy: 0.992
#
# valid writing
# EPOCH 8 Batch 2000 ...
# Validation loss = 0.301
# Validation Accuracy = 0.927
#
# Batch 2100 Train Loss: 0.066 Train Accuracy: 0.992
#
# valid writing
# EPOCH 8 Batch 2100 ...
# Validation loss = 0.302
# Validation Accuracy = 0.929
#
# Batch 2200 Train Loss: 0.041 Train Accuracy: 0.992
#
# valid writing
# EPOCH 9 Batch 2200 ...
# Validation loss = 0.273
# Validation Accuracy = 0.932
#
# Batch 2300 Train Loss: 0.104 Train Accuracy: 0.977
#
# valid writing
# EPOCH 9 Batch 2300 ...
# Validation loss = 0.322
# Validation Accuracy = 0.924
#
# Batch 2400 Train Loss: 0.103 Train Accuracy: 0.977
#
# valid writing
# EPOCH 9 Batch 2400 ...
# Validation loss = 0.276
# Validation Accuracy = 0.933
#
# Batch 2500 Train Loss: 0.061 Train Accuracy: 0.992
#
# valid writing
# EPOCH 10 Batch 2500 ...
# Validation loss = 0.265
# Validation Accuracy = 0.924
#
# Batch 2600 Train Loss: 0.040 Train Accuracy: 1.000
#
# valid writing
# EPOCH 10 Batch 2600 ...
# Validation loss = 0.262
# Validation Accuracy = 0.925
#
# Batch 2700 Train Loss: 0.047 Train Accuracy: 0.992
#
# valid writing
# EPOCH 10 Batch 2700 ...
# Validation loss = 0.214
# Validation Accuracy = 0.941
#
# Batch 2800 Train Loss: 0.021 Train Accuracy: 1.000
#
# valid writing
# EPOCH 11 Batch 2800 ...
# Validation loss = 0.243
# Validation Accuracy = 0.938
#
# Batch 2900 Train Loss: 0.101 Train Accuracy: 0.984
#
# valid writing
# EPOCH 11 Batch 2900 ...
# Validation loss = 0.236
# Validation Accuracy = 0.935
#
# Batch 3000 Train Loss: 0.077 Train Accuracy: 0.992
#
# valid writing
# EPOCH 12 Batch 3000 ...
# Validation loss = 0.248
# Validation Accuracy = 0.931
#
# Batch 3100 Train Loss: 0.056 Train Accuracy: 0.992
#
# valid writing
# EPOCH 12 Batch 3100 ...
# Validation loss = 0.276
# Validation Accuracy = 0.926
#
# Batch 3200 Train Loss: 0.046 Train Accuracy: 0.992
#
# valid writing
# EPOCH 12 Batch 3200 ...
# Validation loss = 0.282
# Validation Accuracy = 0.941
#
# Batch 3300 Train Loss: 0.029 Train Accuracy: 0.992
#
# valid writing
# EPOCH 13 Batch 3300 ...
# Validation loss = 0.232
# Validation Accuracy = 0.943
#
# Batch 3400 Train Loss: 0.022 Train Accuracy: 1.000
#
# valid writing
# EPOCH 13 Batch 3400 ...
# Validation loss = 0.279
# Validation Accuracy = 0.933
#
# Batch 3500 Train Loss: 0.167 Train Accuracy: 0.984
#
# valid writing
# EPOCH 13 Batch 3500 ...
# Validation loss = 0.309
# Validation Accuracy = 0.938
#
# Batch 3600 Train Loss: 0.016 Train Accuracy: 1.000
#
# valid writing
# EPOCH 14 Batch 3600 ...
# Validation loss = 0.261
# Validation Accuracy = 0.937
#
# Batch 3700 Train Loss: 0.027 Train Accuracy: 0.992
#
# valid writing
# EPOCH 14 Batch 3700 ...
# Validation loss = 0.304
# Validation Accuracy = 0.929
#
# Batch 3800 Train Loss: 0.039 Train Accuracy: 0.992
#
# valid writing
# EPOCH 14 Batch 3800 ...
# Validation loss = 0.310
# Validation Accuracy = 0.930
#
# Batch 3900 Train Loss: 0.019 Train Accuracy: 1.000
#
# valid writing
# EPOCH 15 Batch 3900 ...
# Validation loss = 0.263
# Validation Accuracy = 0.945
#
# Batch 4000 Train Loss: 0.020 Train Accuracy: 1.000
#
# valid writing
# EPOCH 15 Batch 4000 ...
# Validation loss = 0.276
# Validation Accuracy = 0.941
#
# Batch 4100 Train Loss: 0.019 Train Accuracy: 1.000
#
# valid writing
# EPOCH 16 Batch 4100 ...
# Validation loss = 0.218
# Validation Accuracy = 0.947
#
# Batch 4200 Train Loss: 0.021 Train Accuracy: 0.992
#
# valid writing
# EPOCH 16 Batch 4200 ...
# Validation loss = 0.242
# Validation Accuracy = 0.942
#
# Batch 4300 Train Loss: 0.039 Train Accuracy: 0.992
#
# valid writing
# EPOCH 16 Batch 4300 ...
# Validation loss = 0.206
# Validation Accuracy = 0.945
#
# Batch 4400 Train Loss: 0.022 Train Accuracy: 0.992
#
# valid writing
# EPOCH 17 Batch 4400 ...
# Validation loss = 0.305
# Validation Accuracy = 0.929
#
# Batch 4500 Train Loss: 0.020 Train Accuracy: 1.000
#
# valid writing
# EPOCH 17 Batch 4500 ...
# Validation loss = 0.220
# Validation Accuracy = 0.955
#
# Batch 4600 Train Loss: 0.011 Train Accuracy: 1.000
#
# valid writing
# EPOCH 17 Batch 4600 ...
# Validation loss = 0.236
# Validation Accuracy = 0.941
#
# Batch 4700 Train Loss: 0.014 Train Accuracy: 1.000
#
# valid writing
# EPOCH 18 Batch 4700 ...
# Validation loss = 0.252
# Validation Accuracy = 0.941
#
# Batch 4800 Train Loss: 0.033 Train Accuracy: 1.000
#
# valid writing
# EPOCH 18 Batch 4800 ...
# Validation loss = 0.248
# Validation Accuracy = 0.939
#
# Batch 4900 Train Loss: 0.024 Train Accuracy: 0.992
#
# valid writing
# EPOCH 19 Batch 4900 ...
# Validation loss = 0.301
# Validation Accuracy = 0.946
#
# Batch 5000 Train Loss: 0.043 Train Accuracy: 0.992
#
# valid writing
# EPOCH 19 Batch 5000 ...
# Validation loss = 0.319
# Validation Accuracy = 0.939
#
# Batch 5100 Train Loss: 0.020 Train Accuracy: 0.992
#
# valid writing
# EPOCH 19 Batch 5100 ...
# Validation loss = 0.272
# Validation Accuracy = 0.950
#
# Batch 5200 Train Loss: 0.023 Train Accuracy: 1.000
#
# valid writing
# EPOCH 20 Batch 5200 ...
# Validation loss = 0.287
# Validation Accuracy = 0.941
#
# Batch 5300 Train Loss: 0.017 Train Accuracy: 1.000
#
# valid writing
# EPOCH 20 Batch 5300 ...
# Validation loss = 0.284
# Validation Accuracy = 0.948
#
# Batch 5400 Train Loss: 0.025 Train Accuracy: 0.984
#
# valid writing
# EPOCH 20 Batch 5400 ...
# Validation loss = 0.265
# Validation Accuracy = 0.937
#
# Batch 5500 Train Loss: 0.031 Train Accuracy: 0.992
#
# valid writing
# EPOCH 21 Batch 5500 ...
# Validation loss = 0.272
# Validation Accuracy = 0.935
#
# Batch 5600 Train Loss: 0.033 Train Accuracy: 0.992
#
# valid writing
# EPOCH 21 Batch 5600 ...
# Validation loss = 0.232
# Validation Accuracy = 0.946
#
# Batch 5700 Train Loss: 0.004 Train Accuracy: 1.000
#
# valid writing
# EPOCH 21 Batch 5700 ...
# Validation loss = 0.304
# Validation Accuracy = 0.942
#
# Batch 5800 Train Loss: 0.004 Train Accuracy: 1.000
#
# valid writing
# EPOCH 22 Batch 5800 ...
# Validation loss = 0.308
# Validation Accuracy = 0.950
# Batch 5900 Train Loss: 0.015 Train Accuracy: 1.000
#
# valid writing
# EPOCH 22 Batch 5900 ...
# Validation loss = 0.202
# Validation Accuracy = 0.949
#
# Batch 6000 Train Loss: 0.012 Train Accuracy: 1.000
#
# valid writing
# EPOCH 23 Batch 6000 ...
# Validation loss = 0.318
# Validation Accuracy = 0.936
#
# Batch 6100 Train Loss: 0.021 Train Accuracy: 0.992
#
# valid writing
# EPOCH 23 Batch 6100 ...
# Validation loss = 0.356
# Validation Accuracy = 0.935
#
# Batch 6200 Train Loss: 0.016 Train Accuracy: 1.000
#
# valid writing
# EPOCH 23 Batch 6200 ...
# Validation loss = 0.274
# Validation Accuracy = 0.942
#
# Batch 6300 Train Loss: 0.017 Train Accuracy: 1.000
#
# valid writing
# EPOCH 24 Batch 6300 ...
# Validation loss = 0.289
# Validation Accuracy = 0.941
#
# Batch 6400 Train Loss: 0.030 Train Accuracy: 0.992
#
# valid writing
# EPOCH 24 Batch 6400 ...
# Validation loss = 0.279
# Validation Accuracy = 0.949
#
# Batch 6500 Train Loss: 0.008 Train Accuracy: 1.000
#
# valid writing
# EPOCH 24 Batch 6500 ...
# Validation loss = 0.259
# Validation Accuracy = 0.947
#
# Batch 6600 Train Loss: 0.016 Train Accuracy: 1.000
#
# valid writing
# EPOCH 25 Batch 6600 ...
# Validation loss = 0.316
# Validation Accuracy = 0.937
#
# Batch 6700 Train Loss: 0.016 Train Accuracy: 0.992
#
# valid writing
# EPOCH 25 Batch 6700 ...
# Validation loss = 0.292
# Validation Accuracy = 0.951
#
# Batch 6800 Train Loss: 0.018 Train Accuracy: 1.000
#
# valid writing
# EPOCH 25 Batch 6800 ...
# Validation loss = 0.299
# Validation Accuracy = 0.954
#
# Batch 6900 Train Loss: 0.009 Train Accuracy: 1.000
#
# valid writing
# EPOCH 26 Batch 6900 ...
# Validation loss = 0.315
# Validation Accuracy = 0.943
#
# Batch 7000 Train Loss: 0.009 Train Accuracy: 1.000
#
# valid writing
# EPOCH 26 Batch 7000 ...
# Validation loss = 0.293
# Validation Accuracy = 0.945
#
# Batch 7100 Train Loss: 0.006 Train Accuracy: 1.000
#
# valid writing
# EPOCH 27 Batch 7100 ...
# Validation loss = 0.320
# Validation Accuracy = 0.929
#
# Batch 7200 Train Loss: 0.005 Train Accuracy: 1.000
#
# valid writing
# EPOCH 27 Batch 7200 ...
# Validation loss = 0.267
# Validation Accuracy = 0.949
#
# Batch 7300 Train Loss: 0.015 Train Accuracy: 1.000
#
# valid writing
# EPOCH 27 Batch 7300 ...
# Validation loss = 0.292
# Validation Accuracy = 0.951
#
# Batch 7400 Train Loss: 0.017 Train Accuracy: 0.992
#
# valid writing
# EPOCH 28 Batch 7400 ...
# Validation loss = 0.236
# Validation Accuracy = 0.946
#
# Batch 7500 Train Loss: 0.006 Train Accuracy: 1.000
#
# valid writing
# EPOCH 28 Batch 7500 ...
# Validation loss = 0.341
# Validation Accuracy = 0.946
#
# Batch 7600 Train Loss: 0.022 Train Accuracy: 0.992
#
# valid writing
# EPOCH 28 Batch 7600 ...
# Validation loss = 0.272
# Validation Accuracy = 0.949
#
# Batch 7700 Train Loss: 0.002 Train Accuracy: 1.000
#
# valid writing
# EPOCH 29 Batch 7700 ...
# Validation loss = 0.308
# Validation Accuracy = 0.941
#
# Batch 7800 Train Loss: 0.012 Train Accuracy: 1.000
#
# valid writing
# EPOCH 29 Batch 7800 ...
# Validation loss = 0.356
# Validation Accuracy = 0.940
#
# Batch 7900 Train Loss: 0.011 Train Accuracy: 1.000
#
# valid writing
# EPOCH 30 Batch 7900 ...
# Validation loss = 0.321
# Validation Accuracy = 0.935
#
# Batch 8000 Train Loss: 0.018 Train Accuracy: 0.992
#
# valid writing
# EPOCH 30 Batch 8000 ...
# Validation loss = 0.290
# Validation Accuracy = 0.950
#
# Batch 8100 Train Loss: 0.013 Train Accuracy: 1.000
#
# valid writing
# EPOCH 30 Batch 8100 ...
# Validation loss = 0.294
# Validation Accuracy = 0.940
#
# Batch 8200 Train Loss: 0.005 Train Accuracy: 1.000
#
# valid writing
# EPOCH 31 Batch 8200 ...
# Validation loss = 0.295
# Validation Accuracy = 0.946
#
# Batch 8300 Train Loss: 0.024 Train Accuracy: 0.977
#
# valid writing
# EPOCH 31 Batch 8300 ...
# Validation loss = 0.279
# Validation Accuracy = 0.942
#
# Batch 8400 Train Loss: 0.029 Train Accuracy: 0.992
#
# valid writing
# EPOCH 31 Batch 8400 ...
# Validation loss = 0.336
# Validation Accuracy = 0.946
#
# Batch 8500 Train Loss: 0.011 Train Accuracy: 1.000
#
# valid writing
# EPOCH 32 Batch 8500 ...
# Validation loss = 0.245
# Validation Accuracy = 0.949
#
# Batch 8600 Train Loss: 0.008 Train Accuracy: 1.000
#
# valid writing
# EPOCH 32 Batch 8600 ...
# Validation loss = 0.301
# Validation Accuracy = 0.939
#
# Batch 8700 Train Loss: 0.002 Train Accuracy: 1.000
#
# valid writing
# EPOCH 32 Batch 8700 ...
# Validation loss = 0.312
# Validation Accuracy = 0.948
#
# Batch 8800 Train Loss: 0.021 Train Accuracy: 0.992
#
# valid writing
# EPOCH 33 Batch 8800 ...
# Validation loss = 0.289
# Validation Accuracy = 0.953
#
# Batch 8900 Train Loss: 0.023 Train Accuracy: 0.992
#
# valid writing
# EPOCH 33 Batch 8900 ...
# Validation loss = 0.254
# Validation Accuracy = 0.949
#
# Batch 9000 Train Loss: 0.005 Train Accuracy: 1.000
#
# valid writing
# EPOCH 34 Batch 9000 ...
# Validation loss = 0.356
# Validation Accuracy = 0.949
#
# Batch 9100 Train Loss: 0.024 Train Accuracy: 0.992
#
# valid writing
# EPOCH 34 Batch 9100 ...
# Validation loss = 0.343
# Validation Accuracy = 0.947
#
# Batch 9200 Train Loss: 0.016 Train Accuracy: 0.992
#
# valid writing
# EPOCH 34 Batch 9200 ...
# Validation loss = 0.360
# Validation Accuracy = 0.946
#
# Batch 9300 Train Loss: 0.020 Train Accuracy: 0.992
#
# valid writing
# EPOCH 35 Batch 9300 ...
# Validation loss = 0.233
# Validation Accuracy = 0.950
#
# Batch 9400 Train Loss: 0.013 Train Accuracy: 0.992
#
# valid writing
# EPOCH 35 Batch 9400 ...
# Validation loss = 0.263
# Validation Accuracy = 0.951
#
# Batch 9500 Train Loss: 0.018 Train Accuracy: 1.000
#
# valid writing
# EPOCH 35 Batch 9500 ...
# Validation loss = 0.251
# Validation Accuracy = 0.951
#
# Batch 9600 Train Loss: 0.021 Train Accuracy: 0.992
#
# valid writing
# EPOCH 36 Batch 9600 ...
# Validation loss = 0.273
# Validation Accuracy = 0.945
#
# Batch 9700 Train Loss: 0.018 Train Accuracy: 0.992
#
# valid writing
# EPOCH 36 Batch 9700 ...
# Validation loss = 0.220
# Validation Accuracy = 0.949
#
# Batch 9800 Train Loss: 0.003 Train Accuracy: 1.000
#
# valid writing
# EPOCH 37 Batch 9800 ...
# Validation loss = 0.255
# Validation Accuracy = 0.938
#
# Batch 9900 Train Loss: 0.007 Train Accuracy: 1.000
#
# valid writing
# EPOCH 37 Batch 9900 ...
# Validation loss = 0.207
# Validation Accuracy = 0.954
#
# Batch 10000 Train Loss: 0.005 Train Accuracy: 1.000
#
# valid writing
# EPOCH 37 Batch 10000 ...
# Validation loss = 0.279
# Validation Accuracy = 0.943
#
# Batch 10100 Train Loss: 0.008 Train Accuracy: 1.000
#
# valid writing
# EPOCH 38 Batch 10100 ...
# Validation loss = 0.224
# Validation Accuracy = 0.949
#
# Batch 10200 Train Loss: 0.001 Train Accuracy: 1.000
#
# valid writing
# EPOCH 38 Batch 10200 ...
# Validation loss = 0.276
# Validation Accuracy = 0.947
#
# Batch 10300 Train Loss: 0.005 Train Accuracy: 1.000
#
# valid writing
# EPOCH 38 Batch 10300 ...
# Validation loss = 0.295
# Validation Accuracy = 0.938
#
# Batch 10400 Train Loss: 0.008 Train Accuracy: 1.000
#
# valid writing
# EPOCH 39 Batch 10400 ...
# Validation loss = 0.276
# Validation Accuracy = 0.947
#
# Batch 10500 Train Loss: 0.003 Train Accuracy: 1.000
#
# valid writing
# EPOCH 39 Batch 10500 ...
# Validation loss = 0.283
# Validation Accuracy = 0.949
#
# Batch 10600 Train Loss: 0.003 Train Accuracy: 1.000
#
# valid writing
# EPOCH 39 Batch 10600 ...
# Validation loss = 0.302
# Validation Accuracy = 0.946
#
# Batch 10700 Train Loss: 0.003 Train Accuracy: 1.000
#
# valid writing
# EPOCH 40 Batch 10700 ...
# Validation loss = 0.261
# Validation Accuracy = 0.954
#
# Batch 10800 Train Loss: 0.006 Train Accuracy: 1.000
#
# valid writing
# EPOCH 40 Batch 10800 ...
# Validation loss = 0.395
# Validation Accuracy = 0.942
#
# Training Done

# %% [markdown]
# ## Evaluate the Model
# Once you are completely satisfied with your model, evaluate the performance of the model on the test set.
#
# Be sure to only do this once!
#
# If you were to measure the performance of your trained model on the test set, then improve your model, and then measure the performance of your model on the test set again, that would invalidate your test results. You wouldn't get a true measure of how well your model would perform against real data.
#
# You do not need to modify this section.

# %%
with tf.Session() as sess:
    saver.restore(sess, tf.train.latest_checkpoint(checkpoint_dir))

    test_loss, test_accuracy = evaluate(X_test, y_test)
    print("Test Loss = {:.3f}".format(test_loss))
    print("Test Accuracy = {:.3f}".format(test_accuracy))
# Out:
# Test Loss = 0.315
# Test Accuracy = 0.937
