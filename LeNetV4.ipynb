# %% [markdown]
# # LeNet for Traffic Sign V4
# ![LeNet Architecture](lenet.png)
# Modified from source: Yan LeCun
#
# Author: Peng "Patrick" Su
# Testing augmentation

# %% [markdown]
# ## Load Data
#
# Load the traffic sign data

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import tensorflow as tf
import cv2
# %matplotlib inline

# %%
# Load pickled data
import pickle

# TODO: Fill this in based on where you saved the training and testing data

training_file = '../traffic-signs-data/train.p'
validation_file = '../traffic-signs-data/valid.p'
testing_file = '../traffic-signs-data/test.p'

with open(training_file, mode='rb') as f:
    train = pickle.load(f)
with open(validation_file, mode='rb') as f:
    valid = pickle.load(f)
with open(testing_file, mode='rb') as f:
    test = pickle.load(f)
    
X_train, y_train = train['features'], train['labels']
X_valid, y_valid = valid['features'], valid['labels']
X_test, y_test = test['features'], test['labels']

# %% [markdown]
# The traffic sign data comes as 32x32x3 images, and LeNet accepts 32x32xC images. No need to pad anything.

# %% [markdown]
# ## Preprocess Data
#
# Shuffle the training data.
#
# You do not need to modify this section.

# %%
from sklearn.utils import shuffle

X_train, y_train = shuffle(X_train, y_train)

# %%
from skimage import transform, filters, exposure
import cv2
def augment_image(img,angle_range=(-5, 5),shear_range=10,trans_range=5,brightness=0):
    # rotation
    angle = np.random.uniform(*angle_range)
    rows, cols, _ = img.shape
    Rot_M = cv2.getRotationMatrix2D((cols/2,rows/2), angle, 1)
    # Translation
    tr_x = trans_range*np.random.uniform()-trans_range/2
    tr_y = trans_range*np.random.uniform()-trans_range/2
    Trans_M = np.float32([[1,0,tr_x],[0,1,tr_y]])
    # Shear
    pts1 = np.float32([[5,5],[20,5],[5,20]])
    pt1 = 5+shear_range*np.random.uniform()-shear_range/2
    pt2 = 20+shear_range*np.random.uniform()-shear_range/2
    # Brightness
    pts2 = np.float32([[pt1,5],[pt2,pt1],[5,pt2]])
    shear_M = cv2.getAffineTransform(pts1,pts2)

    img = cv2.warpAffine(img,Rot_M,(cols,rows))
    img = cv2.warpAffine(img,Trans_M,(cols,rows))
    img = cv2.warpAffine(img,shear_M,(cols,rows))

    if brightness == 1:
        img = augment_brightness_camera_images(img)
    
    return img.astype(np.uint8)

# %%
def augment_data(X, y):
    augmented_X = np.zeros([X.shape[0]*3, *X.shape[1:]], dtype = np.uint8)
    augmented_y = np.zeros([y.shape[0]*3, *y.shape[1:]], dtype = np.uint8)
    #print("X dtype : ", X.dtype)
    #print("augmented X dtype : ", augmented_X)
    for i, _ in enumerate(X):
        augmented_X[i] = X[i]
        augmented_y[i] = y[i]
        for j in range(1,3):
            augmented_X[i+j] = augment_image(X[i])
            augmented_y[i+j] = y[i]    
    return augmented_X, augmented_y
X_train, y_train = augment_data(X_train, y_train)

# %%
def normalize(img):
    return (img - 128.)/128.
def hist_eq(img):
    if (len(img.shape)>3): # if you're passing in a collection of images
        num_images = img.shape[0]
        image_shape = img.shape[1:]
        locEqImg = np.zeros([num_images,image_shape[0],image_shape[1],image_shape[2]])
        clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(6,6))
        for i in range(num_images):
            #print("currImg dtype is ", img[i].dtype)
            #img[i] =img[i].astype(np.float32)
            currImg = img[i].squeeze()
            #img_yuv = cv2.cvtColor(currImg, cv2.COLOR_RGB2YUV)
            #img_yuv[:,:,0] = cv2.equalizeHist(img_yuv[:,:,0])
            #tmp = cv2.cvtColor(img_yuv, cv 2.COLOR_YUV2RGB)
            #eqImg[i]=tmp
            
            img_lab = cv2.cvtColor(currImg, cv2.COLOR_RGB2LAB)
            img_lab[:,:,0]=clahe.apply(img_lab[:,:,0])
            tmp = cv2.cvtColor(img_lab, cv2.COLOR_LAB2RGB)
            locEqImg[i] = tmp
    else:
        clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(6,6))
        img_lab = cv2.cvtColor(img, cv2.COLOR_RGB2LAB)
        img_lab[:,:,0]=clahe.apply(img_lab[:,:,0])
        tmp = cv2.cvtColor(img_lab, cv2.COLOR_LAB2RGB)
        locEqImg = tmp
    return locEqImg

X_train = hist_eq(X_train)
X_train = normalize(X_train)
X_train = X_train.astype('float32')

X_valid = hist_eq(X_valid)
X_valid = normalize(X_valid)
X_valid = X_valid.astype('float32')

X_test = hist_eq(X_test)
X_test = normalize(X_test)
X_test = X_test.astype('float32')

# %%
X_train.shape
# Out:
# (104397, 32, 32, 3)

# %%
X_train.dtype
# Out:
# dtype('float32')

# %% [markdown]
# ## Setup TensorFlow
# The `EPOCH` and `BATCH_SIZE` values affect the training speed and model accuracy.
#
# You do not need to modify this section.

# %%
import tensorflow as tf

# %% [markdown]
# ## TODO: Implement LeNet-5
# Implement the [LeNet-5](http://yann.lecun.com/exdb/lenet/) neural network architecture.
#
# This is the only cell you need to edit.
# ### Input
# The LeNet architecture accepts a 32x32xC image as input, where C is the number of color channels. Since MNIST images are grayscale, C is 1 in this case.
#
# ### Architecture
# **Layer 1: Convolutional.** The output shape should be 28x28x6.
#
# **Activation.** Your choice of activation function.
#
# **Pooling.** The output shape should be 14x14x6.
#
# **Layer 2: Convolutional.** The output shape should be 10x10x16.
#
# **Activation.** Your choice of activation function.
#
# **Pooling.** The output shape should be 5x5x16.
#
# **Flatten.** Flatten the output shape of the final pooling layer such that it's 1D instead of 3D. The easiest way to do is by using `tf.contrib.layers.flatten`, which is already imported for you.
#
# **Layer 3: Fully Connected.** This should have 120 outputs.
#
# **Activation.** Your choice of activation function.
#
# **Layer 4: Fully Connected.** This should have 84 outputs.
#
# **Activation.** Your choice of activation function.
#
# **Layer 5: Fully Connected (Logits).** This should have 10 outputs.
#
# ### Output
# Return the result of the 2nd fully connected layer.

# %%
from tensorflow.contrib.layers import flatten

def LeNet(x):    
    # Arguments used for tf.truncated_normal, randomly defines variables for the weights and biases for each layer
    mu = 0
    sigma = 0.1
    weights = {
        'wc1': tf.Variable(tf.truncated_normal([5,5,3,6], mu, sigma)),
        'wc2': tf.Variable(tf.truncated_normal([5,5,6,16], mu, sigma)),
        'wf3': tf.Variable(tf.truncated_normal([5*5*16, 120], mu, sigma)),
        'wf4': tf.Variable(tf.truncated_normal([120, 84], mu, sigma)),
        'wf5': tf.Variable(tf.truncated_normal([84, 43], mu, sigma))}
    biases = {
        'bc1': tf.zeros([6]),
        'bc2': tf.zeros([16]),
        'bf3': tf.zeros([120]),
        'bf4': tf.zeros([84]),
        'bf5': tf.zeros([43]),
    }
    # TODO: Layer 1: Convolutional. Input = 32x32x1. Output = 28x28x6.
    conv1 = tf.nn.conv2d(x, weights['wc1'], strides = [1, 1, 1, 1], padding = 'VALID')
    conv1 = tf.nn.bias_add(conv1, biases['bc1'])
    # TODO: Activation.
    conv1 = tf.nn.relu(conv1)    
    # TODO: Pooling. Input = 28x28x6. Output = 14x14x6.
    conv1 = tf.nn.max_pool(conv1, ksize = [1, 2, 2, 1], strides = [1, 2, 2, 1], padding = 'VALID')
    conv1 = tf.nn.dropout(conv1, keep_prob)
#     flat1 = flatten(conv1, [-1, 14*14*6])
    
    # TODO: Layer 2: Convolutional. Output = 10x10x16.
    conv2 = tf.nn.conv2d(conv1, weights['wc2'], strides = [1, 1, 1, 1], padding = 'VALID')
    conv2 = tf.nn.bias_add(conv2, biases['bc2'])    
    # TODO: Activation.
    conv2 = tf.nn.relu(conv2)
    # TODO: Pooling. Input = 10x10x16. Output = 5x5x16.
    conv2 = tf.nn.max_pool(conv2, ksize = [1, 2, 2, 1], strides = [1, 2, 2, 1], padding = 'VALID')
    conv2 = tf.nn.dropout(conv2, keep_prob)
    # TODO: Flatten. Input = 5x5x8. Output = 200.

#     flat2 = flatten(conv2, [-1, 5*5*16])
#     flat = tf.concat(1, [flat1, flat2])
    
    flat = flatten(conv2, [-1, 5*5*16])
    
    # TODO: Layer 3: Fully Connected. Input = 400. Output = 120.
    fc3 = tf.add(tf.matmul(flat, weights['wf3']), biases['bf3'])
    # TODO: Activation.
    fc3 = tf.nn.relu(fc3)
    # TODO: Layer 4: Fully Connected. Input = 120. Output = 84.
    fc4 = tf.add(tf.matmul(fc3, weights['wf4']), biases['bf4'])
    # TODO: Activation.
    fc4 = tf.nn.relu(fc4)
    # TODO: Layer 5: Fully Connected. Input = 84. Output = 43.
    logits = tf.add(tf.matmul(fc4, weights['wf5']), biases['bf5'])
    
    return logits

# %% [markdown]
# ## Features and Labels
# Train LeNet to classify traffic sign data.
#
# `x` is a placeholder for a batch of input images.
# `y` is a placeholder for a batch of output labels.
#
# You do not need to modify this section.

# %%
x = tf.placeholder(tf.float32, (None, 32, 32, 3))
y = tf.placeholder(tf.int32, (None))
one_hot_y = tf.one_hot(y, 43)
keep_prob = tf.placeholder(tf.float32)

# %% [markdown]
# ## Training Pipeline
# Create a training pipeline that uses the model to classify MNIST data.
#
# You do not need to modify this section.

# %%
rate = 0.001
logits = LeNet(x)
correct_prediction = tf.equal(tf.argmax(logits, 1), tf.argmax(one_hot_y, 1))
accuracy_operation = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))
cross_entropy = tf.nn.softmax_cross_entropy_with_logits(labels=one_hot_y, logits=logits)
loss_operation = tf.reduce_mean(cross_entropy)
optimizer = tf.train.AdamOptimizer(learning_rate = rate)
training_operation = optimizer.minimize(loss_operation)

# %% [markdown]
# ## Model Evaluation
# Evaluate how well the loss and accuracy of the model for a given dataset.
#
# You do not need to modify this section.

# %%
saver = tf.train.Saver(max_to_keep=100)

def evaluate(X_data, y_data):
    num_examples = len(X_data)
    total_accuracy = 0
    total_loss = 0
    sess = tf.get_default_session()
    for offset in range(0, num_examples, BATCH_SIZE):
        batch_x, batch_y = X_data[offset:offset+BATCH_SIZE], y_data[offset:offset+BATCH_SIZE]
        loss, accuracy = sess.run([loss_operation, accuracy_operation], feed_dict={x: batch_x, y: batch_y, keep_prob:1.0})
        total_accuracy += (accuracy * len(batch_x))
        total_loss += (loss * len(batch_x))
    return total_loss / num_examples, total_accuracy / num_examples

# %% [markdown]
# ## Train the Model
# Run the training data through the training pipeline to train the model.
#
# Before each epoch, shuffle the training set.
#
# After each epoch, measure the loss and accuracy of the validation set.
#
# Save the model after training.
#
# You do not need to modify this section.

# %%
import shutil
save_dir = 'LeNetV4'
out_dir = out_dir = os.path.abspath(os.path.join(os.path.curdir, "../Traffic-Sign-Classifier-runs", save_dir))
if os.path.exists(out_dir):
    shutil.rmtree(out_dir)
train_summary_dir = os.path.join(out_dir, "train")        
valid_summary_dir = os.path.join(out_dir, "valid")
checkpoint_dir = os.path.join(out_dir, "checkpoints")
if not os.path.exists(checkpoint_dir):
    os.makedirs(checkpoint_dir)
checkpoint_prefix = os.path.join(checkpoint_dir,"model")
checkpoint_every = 100
train_summary_every = 100
valid_summary_every = 100

EPOCHS = 40
BATCH_SIZE = 256

with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    num_examples = len(X_train)
    
    print("Training...")
    print()
    global_step = 0
    train_summary_writer = tf.summary.FileWriter(train_summary_dir, sess.graph)
    valid_summary_writer = tf.summary.FileWriter(valid_summary_dir, sess.graph)
    for i in range(EPOCHS):
        X_train, y_train = shuffle(X_train, y_train)
        for offset in range(0, num_examples, BATCH_SIZE):
            end = offset + BATCH_SIZE
            batch_x, batch_y = X_train[offset:end], y_train[offset:end]
            sess.run(training_operation, feed_dict={x: batch_x, y: batch_y, keep_prob:0.6})
            global_step += 1
            if global_step % train_summary_every == 0:
                train_loss, train_accuracy = evaluate(batch_x, batch_y)
                train_summaries = tf.Summary()
                train_summaries.value.add(tag='Train Loss', simple_value=train_loss)
                train_summaries.value.add(tag='Train Accuracy', simple_value=train_accuracy)
                train_summary_writer.add_summary(train_summaries, global_step)
                print("Batch {} Train Loss: {:.3f} Train Accuracy: {:.3f}".format(global_step, train_loss, train_accuracy))
                print()
            if global_step % valid_summary_every == 0:
                validation_loss, validation_accuracy = evaluate(X_valid, y_valid)
                valid_summaries = tf.Summary()
                valid_summaries.value.add(tag='Validation Loss', simple_value=validation_loss)
                valid_summaries.value.add(tag='Validation Accuracy', simple_value=validation_accuracy)
                print("valid writing")
                valid_summary_writer.add_summary(valid_summaries, global_step)
                print("EPOCH {} Batch {} ...".format(i+1, global_step))
                print("Validation loss = {:.3f}".format(validation_loss))
                print("Validation Accuracy = {:.3f}".format(validation_accuracy))
                print()
            if global_step % checkpoint_every == 0:
                saver.save(sess, checkpoint_prefix, global_step=global_step)            
    print("Training Done")
# Out:
# Training...
#
# Batch 100 Train Loss: 1.214 Train Accuracy: 0.691
#
# valid writing
# EPOCH 1 Batch 100 ...
# Validation loss = 3.385
# Validation Accuracy = 0.123
#
# Batch 200 Train Loss: 0.679 Train Accuracy: 0.816
#
# valid writing
# EPOCH 1 Batch 200 ...
# Validation loss = 2.262
# Validation Accuracy = 0.395
#
# Batch 300 Train Loss: 0.447 Train Accuracy: 0.883
#
# valid writing
# EPOCH 1 Batch 300 ...
# Validation loss = 1.424
# Validation Accuracy = 0.601
#
# Batch 400 Train Loss: 0.312 Train Accuracy: 0.910
#
# valid writing
# EPOCH 1 Batch 400 ...
# Validation loss = 1.035
# Validation Accuracy = 0.701
#
# Batch 500 Train Loss: 0.267 Train Accuracy: 0.941
#
# valid writing
# EPOCH 2 Batch 500 ...
# Validation loss = 0.807
# Validation Accuracy = 0.777
#
# Batch 600 Train Loss: 0.221 Train Accuracy: 0.938
#
# valid writing
# EPOCH 2 Batch 600 ...
# Validation loss = 0.690
# Validation Accuracy = 0.799
#
# Batch 700 Train Loss: 0.162 Train Accuracy: 0.969
#
# valid writing
# EPOCH 2 Batch 700 ...
# Validation loss = 0.624
# Validation Accuracy = 0.834
#
# Batch 800 Train Loss: 0.142 Train Accuracy: 0.961
#
# valid writing
# EPOCH 2 Batch 800 ...
# Validation loss = 0.568
# Validation Accuracy = 0.850
#
# Batch 900 Train Loss: 0.133 Train Accuracy: 0.965
#
# valid writing
# EPOCH 3 Batch 900 ...
# Validation loss = 0.507
# Validation Accuracy = 0.860
#
# Batch 1000 Train Loss: 0.107 Train Accuracy: 0.977
#
# valid writing
# EPOCH 3 Batch 1000 ...
# Validation loss = 0.468
# Validation Accuracy = 0.893
#
# Batch 1100 Train Loss: 0.123 Train Accuracy: 0.965
#
# valid writing
# EPOCH 3 Batch 1100 ...
# Validation loss = 0.425
# Validation Accuracy = 0.887
#
# Batch 1200 Train Loss: 0.114 Train Accuracy: 0.973
#
# valid writing
# EPOCH 3 Batch 1200 ...
# Validation loss = 0.399
# Validation Accuracy = 0.900
#
# Batch 1300 Train Loss: 0.114 Train Accuracy: 0.965
#
# valid writing
# EPOCH 4 Batch 1300 ...
# Validation loss = 0.385
# Validation Accuracy = 0.903
#
# Batch 1400 Train Loss: 0.090 Train Accuracy: 0.984
#
# valid writing
# EPOCH 4 Batch 1400 ...
# Validation loss = 0.377
# Validation Accuracy = 0.912
#
# Batch 1500 Train Loss: 0.058 Train Accuracy: 0.992
#
# valid writing
# EPOCH 4 Batch 1500 ...
# Validation loss = 0.350
# Validation Accuracy = 0.905
#
# Batch 1600 Train Loss: 0.096 Train Accuracy: 0.969
#
# valid writing
# EPOCH 4 Batch 1600 ...
# Validation loss = 0.346
# Validation Accuracy = 0.908
#
# Batch 1700 Train Loss: 0.080 Train Accuracy: 0.977
#
# valid writing
# EPOCH 5 Batch 1700 ...
# Validation loss = 0.308
# Validation Accuracy = 0.924
#
# Batch 1800 Train Loss: 0.041 Train Accuracy: 0.992
#
# valid writing
# EPOCH 5 Batch 1800 ...
# Validation loss = 0.309
# Validation Accuracy = 0.920
#
# Batch 1900 Train Loss: 0.055 Train Accuracy: 0.992
#
# valid writing
# EPOCH 5 Batch 1900 ...
# Validation loss = 0.313
# Validation Accuracy = 0.921
#
# Batch 2000 Train Loss: 0.048 Train Accuracy: 0.996
#
# valid writing
# EPOCH 5 Batch 2000 ...
# Validation loss = 0.278
# Validation Accuracy = 0.935
#
# Batch 2100 Train Loss: 0.052 Train Accuracy: 0.988
#
# valid writing
# EPOCH 6 Batch 2100 ...
# Validation loss = 0.290
# Validation Accuracy = 0.921
#
# Batch 2200 Train Loss: 0.107 Train Accuracy: 0.977
#
# valid writing
# EPOCH 6 Batch 2200 ...
# Validation loss = 0.302
# Validation Accuracy = 0.918
#
# Batch 2300 Train Loss: 0.048 Train Accuracy: 0.992
#
# valid writing
# EPOCH 6 Batch 2300 ...
# Validation loss = 0.254
# Validation Accuracy = 0.938
#
# Batch 2400 Train Loss: 0.048 Train Accuracy: 0.992
#
# valid writing
# EPOCH 6 Batch 2400 ...
# Validation loss = 0.263
# Validation Accuracy = 0.929
#
# Batch 2500 Train Loss: 0.056 Train Accuracy: 0.988
#
# valid writing
# EPOCH 7 Batch 2500 ...
# Validation loss = 0.258
# Validation Accuracy = 0.922
#
# Batch 2600 Train Loss: 0.036 Train Accuracy: 0.988
#
# valid writing
# EPOCH 7 Batch 2600 ...
# Validation loss = 0.228
# Validation Accuracy = 0.944
#
# Batch 2700 Train Loss: 0.047 Train Accuracy: 0.988
#
# valid writing
# EPOCH 7 Batch 2700 ...
# Validation loss = 0.232
# Validation Accuracy = 0.936
#
# Batch 2800 Train Loss: 0.026 Train Accuracy: 0.992
#
# valid writing
# EPOCH 7 Batch 2800 ...
# Validation loss = 0.228
# Validation Accuracy = 0.943
#
# Batch 2900 Train Loss: 0.021 Train Accuracy: 1.000
#
# valid writing
# EPOCH 8 Batch 2900 ...
# Validation loss = 0.220
# Validation Accuracy = 0.943
#
# Batch 3000 Train Loss: 0.049 Train Accuracy: 0.992
#
# valid writing
# EPOCH 8 Batch 3000 ...
# Validation loss = 0.213
# Validation Accuracy = 0.941
#
# Batch 3100 Train Loss: 0.052 Train Accuracy: 0.980
#
# valid writing
# EPOCH 8 Batch 3100 ...
# Validation loss = 0.230
# Validation Accuracy = 0.931
#
# Batch 3200 Train Loss: 0.031 Train Accuracy: 0.992
#
# valid writing
# EPOCH 8 Batch 3200 ...
# Validation loss = 0.218
# Validation Accuracy = 0.940
#
# Batch 3300 Train Loss: 0.043 Train Accuracy: 0.984
#
# valid writing
# EPOCH 9 Batch 3300 ...
# Validation loss = 0.211
# Validation Accuracy = 0.945
#
# Batch 3400 Train Loss: 0.020 Train Accuracy: 1.000
#
# valid writing
# EPOCH 9 Batch 3400 ...
# Validation loss = 0.209
# Validation Accuracy = 0.939
#
# Batch 3500 Train Loss: 0.061 Train Accuracy: 0.988
#
# valid writing
# EPOCH 9 Batch 3500 ...
# Validation loss = 0.214
# Validation Accuracy = 0.939
#
# Batch 3600 Train Loss: 0.080 Train Accuracy: 0.977
#
# valid writing
# EPOCH 9 Batch 3600 ...
# Validation loss = 0.227
# Validation Accuracy = 0.931
#
# Batch 3700 Train Loss: 0.024 Train Accuracy: 0.996
#
# valid writing
# EPOCH 10 Batch 3700 ...
# Validation loss = 0.233
# Validation Accuracy = 0.939
#
# Batch 3800 Train Loss: 0.025 Train Accuracy: 0.996
#
# valid writing
# EPOCH 10 Batch 3800 ...
# Validation loss = 0.208
# Validation Accuracy = 0.938
#
# Batch 3900 Train Loss: 0.018 Train Accuracy: 1.000
#
# valid writing
# EPOCH 10 Batch 3900 ...
# Validation loss = 0.200
# Validation Accuracy = 0.941
#
# Batch 4000 Train Loss: 0.029 Train Accuracy: 0.996
#
# valid writing
# EPOCH 10 Batch 4000 ...
# Validation loss = 0.179
# Validation Accuracy = 0.949
#
# Batch 4100 Train Loss: 0.025 Train Accuracy: 1.000
#
# valid writing
# EPOCH 11 Batch 4100 ...
# Validation loss = 0.211
# Validation Accuracy = 0.939
#
# Batch 4200 Train Loss: 0.020 Train Accuracy: 0.996
#
# valid writing
# EPOCH 11 Batch 4200 ...
# Validation loss = 0.172
# Validation Accuracy = 0.951
#
# Batch 4300 Train Loss: 0.044 Train Accuracy: 0.992
#
# valid writing
# EPOCH 11 Batch 4300 ...
# Validation loss = 0.204
# Validation Accuracy = 0.939
#
# Batch 4400 Train Loss: 0.047 Train Accuracy: 0.980
#
# valid writing
# EPOCH 11 Batch 4400 ...
# Validation loss = 0.237
# Validation Accuracy = 0.924
#
# Batch 4500 Train Loss: 0.022 Train Accuracy: 1.000
#
# valid writing
# EPOCH 12 Batch 4500 ...
# Validation loss = 0.180
# Validation Accuracy = 0.951
#
# Batch 4600 Train Loss: 0.026 Train Accuracy: 1.000
#
# valid writing
# EPOCH 12 Batch 4600 ...
# Validation loss = 0.187
# Validation Accuracy = 0.947
#
# Batch 4700 Train Loss: 0.032 Train Accuracy: 0.988
#
# valid writing
# EPOCH 12 Batch 4700 ...
# Validation loss = 0.204
# Validation Accuracy = 0.941
#
# Batch 4800 Train Loss: 0.021 Train Accuracy: 0.996
#
# valid writing
# EPOCH 12 Batch 4800 ...
# Validation loss = 0.194
# Validation Accuracy = 0.940
#
# Batch 4900 Train Loss: 0.020 Train Accuracy: 1.000
#
# valid writing
# EPOCH 13 Batch 4900 ...
# Validation loss = 0.194
# Validation Accuracy = 0.942
#
# Batch 5000 Train Loss: 0.014 Train Accuracy: 1.000
#
# valid writing
# EPOCH 13 Batch 5000 ...
# Validation loss = 0.184
# Validation Accuracy = 0.944
#
# Batch 5100 Train Loss: 0.017 Train Accuracy: 1.000
#
# valid writing
# EPOCH 13 Batch 5100 ...
# Validation loss = 0.173
# Validation Accuracy = 0.947
#
# Batch 5200 Train Loss: 0.028 Train Accuracy: 0.984
#
# valid writing
# EPOCH 13 Batch 5200 ...
# Validation loss = 0.161
# Validation Accuracy = 0.956
#
# Batch 5300 Train Loss: 0.019 Train Accuracy: 0.996
#
# valid writing
# EPOCH 13 Batch 5300 ...
# Validation loss = 0.181
# Validation Accuracy = 0.946
#
# Batch 5400 Train Loss: 0.034 Train Accuracy: 0.996
#
# valid writing
# EPOCH 14 Batch 5400 ...
# Validation loss = 0.187
# Validation Accuracy = 0.943
#
# Batch 5500 Train Loss: 0.017 Train Accuracy: 1.000
#
# valid writing
# EPOCH 14 Batch 5500 ...
# Validation loss = 0.172
# Validation Accuracy = 0.953
#
# Batch 5600 Train Loss: 0.011 Train Accuracy: 1.000
#
# valid writing
# EPOCH 14 Batch 5600 ...
# Validation loss = 0.161
# Validation Accuracy = 0.950
#
# Batch 5700 Train Loss: 0.023 Train Accuracy: 0.992
#
# valid writing
# EPOCH 14 Batch 5700 ...
# Validation loss = 0.171
# Validation Accuracy = 0.948
#
# Batch 5800 Train Loss: 0.021 Train Accuracy: 0.996
#
# valid writing
# EPOCH 15 Batch 5800 ...
# Validation loss = 0.159
# Validation Accuracy = 0.956
# Batch 5900 Train Loss: 0.011 Train Accuracy: 1.000
#
# valid writing
# EPOCH 15 Batch 5900 ...
# Validation loss = 0.153
# Validation Accuracy = 0.956
#
# Batch 6000 Train Loss: 0.023 Train Accuracy: 1.000
#
# valid writing
# EPOCH 15 Batch 6000 ...
# Validation loss = 0.160
# Validation Accuracy = 0.953
#
# Batch 6100 Train Loss: 0.026 Train Accuracy: 0.996
#
# valid writing
# EPOCH 15 Batch 6100 ...
# Validation loss = 0.156
# Validation Accuracy = 0.957
#
# Batch 6200 Train Loss: 0.013 Train Accuracy: 0.996
#
# valid writing
# EPOCH 16 Batch 6200 ...
# Validation loss = 0.153
# Validation Accuracy = 0.953
#
# Batch 6300 Train Loss: 0.047 Train Accuracy: 0.984
#
# valid writing
# EPOCH 16 Batch 6300 ...
# Validation loss = 0.157
# Validation Accuracy = 0.957
#
# Batch 6400 Train Loss: 0.011 Train Accuracy: 1.000
#
# valid writing
# EPOCH 16 Batch 6400 ...
# Validation loss = 0.155
# Validation Accuracy = 0.954
#
# Batch 6500 Train Loss: 0.009 Train Accuracy: 0.996
#
# valid writing
# EPOCH 16 Batch 6500 ...
# Validation loss = 0.165
# Validation Accuracy = 0.949
#
# Batch 6600 Train Loss: 0.184 Train Accuracy: 0.980
#
# valid writing
# EPOCH 17 Batch 6600 ...
# Validation loss = 0.851
# Validation Accuracy = 0.892
#
# Batch 6700 Train Loss: 0.020 Train Accuracy: 1.000
#
# valid writing
# EPOCH 17 Batch 6700 ...
# Validation loss = 0.174
# Validation Accuracy = 0.948
#
# Batch 6800 Train Loss: 0.015 Train Accuracy: 0.996
#
# valid writing
# EPOCH 17 Batch 6800 ...
# Validation loss = 0.163
# Validation Accuracy = 0.952
#
# Batch 6900 Train Loss: 0.015 Train Accuracy: 0.996
#
# valid writing
# EPOCH 17 Batch 6900 ...
# Validation loss = 0.155
# Validation Accuracy = 0.954
#
# Batch 7000 Train Loss: 0.008 Train Accuracy: 1.000
#
# valid writing
# EPOCH 18 Batch 7000 ...
# Validation loss = 0.182
# Validation Accuracy = 0.945
#
# Batch 7100 Train Loss: 0.009 Train Accuracy: 1.000
#
# valid writing
# EPOCH 18 Batch 7100 ...
# Validation loss = 0.161
# Validation Accuracy = 0.954
#
# Batch 7200 Train Loss: 0.018 Train Accuracy: 0.996
#
# valid writing
# EPOCH 18 Batch 7200 ...
# Validation loss = 0.143
# Validation Accuracy = 0.961
#
# Batch 7300 Train Loss: 0.017 Train Accuracy: 1.000
#
# valid writing
# EPOCH 18 Batch 7300 ...
# Validation loss = 0.145
# Validation Accuracy = 0.961
#
# Batch 7400 Train Loss: 0.015 Train Accuracy: 0.996
#
# valid writing
# EPOCH 19 Batch 7400 ...
# Validation loss = 0.157
# Validation Accuracy = 0.951
#
# Batch 7500 Train Loss: 0.013 Train Accuracy: 1.000
#
# valid writing
# EPOCH 19 Batch 7500 ...
# Validation loss = 0.176
# Validation Accuracy = 0.945
#
# Batch 7600 Train Loss: 0.015 Train Accuracy: 0.996
#
# valid writing
# EPOCH 19 Batch 7600 ...
# Validation loss = 0.157
# Validation Accuracy = 0.953
#
# Batch 7700 Train Loss: 0.011 Train Accuracy: 0.996
#
# valid writing
# EPOCH 19 Batch 7700 ...
# Validation loss = 0.145
# Validation Accuracy = 0.960
#
# Batch 7800 Train Loss: 0.014 Train Accuracy: 0.996
#
# valid writing
# EPOCH 20 Batch 7800 ...
# Validation loss = 0.151
# Validation Accuracy = 0.954
#
# Batch 7900 Train Loss: 0.008 Train Accuracy: 1.000
#
# valid writing
# EPOCH 20 Batch 7900 ...
# Validation loss = 0.171
# Validation Accuracy = 0.948
#
# Batch 8000 Train Loss: 0.015 Train Accuracy: 1.000
#
# valid writing
# EPOCH 20 Batch 8000 ...
# Validation loss = 0.166
# Validation Accuracy = 0.948
#
# Batch 8100 Train Loss: 0.014 Train Accuracy: 0.996
#
# valid writing
# EPOCH 20 Batch 8100 ...
# Validation loss = 0.158
# Validation Accuracy = 0.953
#
# Batch 8200 Train Loss: 0.013 Train Accuracy: 0.996
#
# valid writing
# EPOCH 21 Batch 8200 ...
# Validation loss = 0.149
# Validation Accuracy = 0.956
#
# Batch 8300 Train Loss: 0.012 Train Accuracy: 1.000
#
# valid writing
# EPOCH 21 Batch 8300 ...
# Validation loss = 0.156
# Validation Accuracy = 0.954
#
# Batch 8400 Train Loss: 0.015 Train Accuracy: 0.996
#
# valid writing
# EPOCH 21 Batch 8400 ...
# Validation loss = 0.142
# Validation Accuracy = 0.957
#
# Batch 8500 Train Loss: 0.008 Train Accuracy: 1.000
#
# valid writing
# EPOCH 21 Batch 8500 ...
# Validation loss = 0.156
# Validation Accuracy = 0.952
#
# Batch 8600 Train Loss: 0.014 Train Accuracy: 1.000
#
# valid writing
# EPOCH 22 Batch 8600 ...
# Validation loss = 0.156
# Validation Accuracy = 0.956
#
# Batch 8700 Train Loss: 0.016 Train Accuracy: 1.000
#
# valid writing
# EPOCH 22 Batch 8700 ...
# Validation loss = 0.154
# Validation Accuracy = 0.956
#
# Batch 8800 Train Loss: 0.008 Train Accuracy: 1.000
#
# valid writing
# EPOCH 22 Batch 8800 ...
# Validation loss = 0.168
# Validation Accuracy = 0.951
#
# Batch 8900 Train Loss: 0.004 Train Accuracy: 1.000
#
# valid writing
# EPOCH 22 Batch 8900 ...
# Validation loss = 0.157
# Validation Accuracy = 0.954
#
# Batch 9000 Train Loss: 0.013 Train Accuracy: 1.000
#
# valid writing
# EPOCH 23 Batch 9000 ...
# Validation loss = 0.152
# Validation Accuracy = 0.954
#
# Batch 9100 Train Loss: 0.009 Train Accuracy: 1.000
#
# valid writing
# EPOCH 23 Batch 9100 ...
# Validation loss = 0.143
# Validation Accuracy = 0.956
#
# Batch 9200 Train Loss: 0.009 Train Accuracy: 1.000
#
# valid writing
# EPOCH 23 Batch 9200 ...
# Validation loss = 0.157
# Validation Accuracy = 0.954
#
# Batch 9300 Train Loss: 0.006 Train Accuracy: 1.000
#
# valid writing
# EPOCH 23 Batch 9300 ...
# Validation loss = 0.159
# Validation Accuracy = 0.952
#
# Batch 9400 Train Loss: 0.012 Train Accuracy: 0.996
#
# valid writing
# EPOCH 24 Batch 9400 ...
# Validation loss = 0.162
# Validation Accuracy = 0.951
#
# Batch 9500 Train Loss: 0.008 Train Accuracy: 1.000
#
# valid writing
# EPOCH 24 Batch 9500 ...
# Validation loss = 0.154
# Validation Accuracy = 0.955
#
# Batch 9600 Train Loss: 0.007 Train Accuracy: 1.000
#
# valid writing
# EPOCH 24 Batch 9600 ...
# Validation loss = 0.181
# Validation Accuracy = 0.946
#
# Batch 9700 Train Loss: 0.049 Train Accuracy: 0.992
#
# valid writing
# EPOCH 24 Batch 9700 ...
# Validation loss = 0.260
# Validation Accuracy = 0.931
#
# Batch 9800 Train Loss: 0.024 Train Accuracy: 1.000
#
# valid writing
# EPOCH 25 Batch 9800 ...
# Validation loss = 0.181
# Validation Accuracy = 0.949
#
# Batch 9900 Train Loss: 0.007 Train Accuracy: 1.000
#
# valid writing
# EPOCH 25 Batch 9900 ...
# Validation loss = 0.156
# Validation Accuracy = 0.955
#
# Batch 10000 Train Loss: 0.009 Train Accuracy: 1.000
#
# valid writing
# EPOCH 25 Batch 10000 ...
# Validation loss = 0.152
# Validation Accuracy = 0.954
#
# Batch 10100 Train Loss: 0.020 Train Accuracy: 0.996
#
# valid writing
# EPOCH 25 Batch 10100 ...
# Validation loss = 0.159
# Validation Accuracy = 0.950
#
# Batch 10200 Train Loss: 0.010 Train Accuracy: 1.000
#
# valid writing
# EPOCH 25 Batch 10200 ...
# Validation loss = 0.152
# Validation Accuracy = 0.953
#
# Batch 10300 Train Loss: 0.023 Train Accuracy: 0.992
#
# valid writing
# EPOCH 26 Batch 10300 ...
# Validation loss = 0.150
# Validation Accuracy = 0.953
#
# Batch 10400 Train Loss: 0.009 Train Accuracy: 1.000
#
# valid writing
# EPOCH 26 Batch 10400 ...
# Validation loss = 0.143
# Validation Accuracy = 0.957
#
# Batch 10500 Train Loss: 0.008 Train Accuracy: 1.000
#
# valid writing
# EPOCH 26 Batch 10500 ...
# Validation loss = 0.150
# Validation Accuracy = 0.955
#
# Batch 10600 Train Loss: 0.006 Train Accuracy: 1.000
#
# valid writing
# EPOCH 26 Batch 10600 ...
# Validation loss = 0.157
# Validation Accuracy = 0.952
#
# Batch 10700 Train Loss: 0.007 Train Accuracy: 1.000
#
# valid writing
# EPOCH 27 Batch 10700 ...
# Validation loss = 0.133
# Validation Accuracy = 0.960
#
# Batch 10800 Train Loss: 0.012 Train Accuracy: 1.000
#
# valid writing
# EPOCH 27 Batch 10800 ...
# Validation loss = 0.138
# Validation Accuracy = 0.960
#
# Batch 10900 Train Loss: 0.014 Train Accuracy: 0.996
#
# valid writing
# EPOCH 27 Batch 10900 ...
# Validation loss = 0.151
# Validation Accuracy = 0.952
#
# Batch 11000 Train Loss: 0.006 Train Accuracy: 1.000
#
# valid writing
# EPOCH 27 Batch 11000 ...
# Validation loss = 0.135
# Validation Accuracy = 0.960
#
# Batch 11100 Train Loss: 0.012 Train Accuracy: 0.992
#
# valid writing
# EPOCH 28 Batch 11100 ...
# Validation loss = 0.147
# Validation Accuracy = 0.959
#
# Batch 11200 Train Loss: 0.009 Train Accuracy: 1.000
#
# valid writing
# EPOCH 28 Batch 11200 ...
# Validation loss = 0.175
# Validation Accuracy = 0.950
#
# Batch 11300 Train Loss: 0.010 Train Accuracy: 1.000
#
# valid writing
# EPOCH 28 Batch 11300 ...
# Validation loss = 0.166
# Validation Accuracy = 0.953
#
# Batch 11400 Train Loss: 0.012 Train Accuracy: 0.996
#
# valid writing
# EPOCH 28 Batch 11400 ...
# Validation loss = 0.156
# Validation Accuracy = 0.956
#
# Batch 11500 Train Loss: 0.015 Train Accuracy: 0.996
#
# valid writing
# EPOCH 29 Batch 11500 ...
# Validation loss = 0.152
# Validation Accuracy = 0.954
#
# Batch 11600 Train Loss: 0.004 Train Accuracy: 1.000
#
# valid writing
# EPOCH 29 Batch 11600 ...
# Validation loss = 0.148
# Validation Accuracy = 0.960
# Batch 11700 Train Loss: 0.003 Train Accuracy: 1.000
#
# valid writing
# EPOCH 29 Batch 11700 ...
# Validation loss = 0.132
# Validation Accuracy = 0.960
#
# Batch 11800 Train Loss: 0.011 Train Accuracy: 0.996
#
# valid writing
# EPOCH 29 Batch 11800 ...
# Validation loss = 0.144
# Validation Accuracy = 0.958
#
# Batch 11900 Train Loss: 0.004 Train Accuracy: 1.000
#
# valid writing
# EPOCH 30 Batch 11900 ...
# Validation loss = 0.153
# Validation Accuracy = 0.954
#
# Batch 12000 Train Loss: 0.015 Train Accuracy: 0.996
#
# valid writing
# EPOCH 30 Batch 12000 ...
# Validation loss = 0.141
# Validation Accuracy = 0.956
#
# Batch 12100 Train Loss: 0.013 Train Accuracy: 1.000
#
# valid writing
# EPOCH 30 Batch 12100 ...
# Validation loss = 0.142
# Validation Accuracy = 0.958
#
# Batch 12200 Train Loss: 0.012 Train Accuracy: 1.000
#
# valid writing
# EPOCH 30 Batch 12200 ...
# Validation loss = 0.137
# Validation Accuracy = 0.962
#
# Batch 12300 Train Loss: 0.016 Train Accuracy: 0.992
#
# valid writing
# EPOCH 31 Batch 12300 ...
# Validation loss = 0.163
# Validation Accuracy = 0.955
#
# Batch 12400 Train Loss: 0.007 Train Accuracy: 0.996
#
# valid writing
# EPOCH 31 Batch 12400 ...
# Validation loss = 0.138
# Validation Accuracy = 0.962
#
# Batch 12500 Train Loss: 0.012 Train Accuracy: 0.996
#
# valid writing
# EPOCH 31 Batch 12500 ...
# Validation loss = 0.153
# Validation Accuracy = 0.961
#
# Batch 12600 Train Loss: 0.004 Train Accuracy: 1.000
#
# valid writing
# EPOCH 31 Batch 12600 ...
# Validation loss = 0.138
# Validation Accuracy = 0.959
#
# Batch 12700 Train Loss: 0.005 Train Accuracy: 1.000
#
# valid writing
# EPOCH 32 Batch 12700 ...
# Validation loss = 0.150
# Validation Accuracy = 0.961
#
# Batch 12800 Train Loss: 0.006 Train Accuracy: 1.000
#
# valid writing
# EPOCH 32 Batch 12800 ...
# Validation loss = 0.131
# Validation Accuracy = 0.964
#
# Batch 12900 Train Loss: 0.014 Train Accuracy: 0.996
#
# valid writing
# EPOCH 32 Batch 12900 ...
# Validation loss = 0.162
# Validation Accuracy = 0.955
#
# Batch 13000 Train Loss: 0.009 Train Accuracy: 1.000
#
# valid writing
# EPOCH 32 Batch 13000 ...
# Validation loss = 0.167
# Validation Accuracy = 0.955
#
# Batch 13100 Train Loss: 0.005 Train Accuracy: 1.000
#
# valid writing
# EPOCH 33 Batch 13100 ...
# Validation loss = 0.177
# Validation Accuracy = 0.947
#
# Batch 13200 Train Loss: 0.014 Train Accuracy: 1.000
#
# valid writing
# EPOCH 33 Batch 13200 ...
# Validation loss = 0.139
# Validation Accuracy = 0.958
#
# Batch 13300 Train Loss: 0.005 Train Accuracy: 1.000
#
# valid writing
# EPOCH 33 Batch 13300 ...
# Validation loss = 0.153
# Validation Accuracy = 0.952
#
# Batch 13400 Train Loss: 0.004 Train Accuracy: 1.000
#
# valid writing
# EPOCH 33 Batch 13400 ...
# Validation loss = 0.133
# Validation Accuracy = 0.960
#
# Batch 13500 Train Loss: 0.007 Train Accuracy: 1.000
#
# valid writing
# EPOCH 34 Batch 13500 ...
# Validation loss = 0.140
# Validation Accuracy = 0.960
#
# Batch 13600 Train Loss: 0.009 Train Accuracy: 1.000
#
# valid writing
# EPOCH 34 Batch 13600 ...
# Validation loss = 0.161
# Validation Accuracy = 0.957
#
# Batch 13700 Train Loss: 0.028 Train Accuracy: 0.996
#
# valid writing
# EPOCH 34 Batch 13700 ...
# Validation loss = 0.172
# Validation Accuracy = 0.952
#
# Batch 13800 Train Loss: 0.013 Train Accuracy: 0.996
#
# valid writing
# EPOCH 34 Batch 13800 ...
# Validation loss = 0.165
# Validation Accuracy = 0.953
#
# Batch 13900 Train Loss: 0.016 Train Accuracy: 0.996
#
# valid writing
# EPOCH 35 Batch 13900 ...
# Validation loss = 0.140
# Validation Accuracy = 0.956
#
# Batch 14000 Train Loss: 0.018 Train Accuracy: 0.996
#
# valid writing
# EPOCH 35 Batch 14000 ...
# Validation loss = 0.272
# Validation Accuracy = 0.933
#
# Batch 14100 Train Loss: 0.012 Train Accuracy: 1.000
#
# valid writing
# EPOCH 35 Batch 14100 ...
# Validation loss = 0.189
# Validation Accuracy = 0.947
#
# Batch 14200 Train Loss: 0.004 Train Accuracy: 1.000
#
# valid writing
# EPOCH 35 Batch 14200 ...
# Validation loss = 0.169
# Validation Accuracy = 0.958
#
# Batch 14300 Train Loss: 0.005 Train Accuracy: 1.000
#
# valid writing
# EPOCH 36 Batch 14300 ...
# Validation loss = 0.172
# Validation Accuracy = 0.952
#
# Batch 14400 Train Loss: 0.011 Train Accuracy: 0.996
#
# valid writing
# EPOCH 36 Batch 14400 ...
# Validation loss = 0.155
# Validation Accuracy = 0.958
#
# Batch 14500 Train Loss: 0.005 Train Accuracy: 1.000
#
# valid writing
# EPOCH 36 Batch 14500 ...
# Validation loss = 0.160
# Validation Accuracy = 0.954
#
# Batch 14600 Train Loss: 0.002 Train Accuracy: 1.000
#
# valid writing
# EPOCH 36 Batch 14600 ...
# Validation loss = 0.154
# Validation Accuracy = 0.959
#
# Batch 14700 Train Loss: 0.003 Train Accuracy: 1.000
#
# valid writing
# EPOCH 37 Batch 14700 ...
# Validation loss = 0.170
# Validation Accuracy = 0.951
#
# Batch 14800 Train Loss: 0.005 Train Accuracy: 1.000
#
# valid writing
# EPOCH 37 Batch 14800 ...
# Validation loss = 0.148
# Validation Accuracy = 0.961
#
# Batch 14900 Train Loss: 0.015 Train Accuracy: 1.000
#
# valid writing
# EPOCH 37 Batch 14900 ...
# Validation loss = 0.144
# Validation Accuracy = 0.955
#
# Batch 15000 Train Loss: 0.010 Train Accuracy: 1.000
#
# valid writing
# EPOCH 37 Batch 15000 ...
# Validation loss = 0.150
# Validation Accuracy = 0.958
#
# Batch 15100 Train Loss: 0.006 Train Accuracy: 1.000
#
# valid writing
# EPOCH 38 Batch 15100 ...
# Validation loss = 0.162
# Validation Accuracy = 0.957
#
# Batch 15200 Train Loss: 0.003 Train Accuracy: 1.000
#
# valid writing
# EPOCH 38 Batch 15200 ...
# Validation loss = 0.159
# Validation Accuracy = 0.961
#
# Batch 15300 Train Loss: 0.002 Train Accuracy: 1.000
#
# valid writing
# EPOCH 38 Batch 15300 ...
# Validation loss = 0.140
# Validation Accuracy = 0.962
#
# Batch 15400 Train Loss: 0.014 Train Accuracy: 0.996
#
# valid writing
# EPOCH 38 Batch 15400 ...
# Validation loss = 0.131
# Validation Accuracy = 0.962
#
# Batch 15500 Train Loss: 0.008 Train Accuracy: 1.000
#
# valid writing
# EPOCH 38 Batch 15500 ...
# Validation loss = 0.140
# Validation Accuracy = 0.960
#
# Batch 15600 Train Loss: 0.022 Train Accuracy: 0.992
#
# valid writing
# EPOCH 39 Batch 15600 ...
# Validation loss = 0.163
# Validation Accuracy = 0.956
#
# Batch 15700 Train Loss: 0.010 Train Accuracy: 0.996
#
# valid writing
# EPOCH 39 Batch 15700 ...
# Validation loss = 0.166
# Validation Accuracy = 0.955
#
# Batch 15800 Train Loss: 0.007 Train Accuracy: 1.000
#
# valid writing
# EPOCH 39 Batch 15800 ...
# Validation loss = 0.149
# Validation Accuracy = 0.954
#
# Batch 15900 Train Loss: 0.003 Train Accuracy: 1.000
#
# valid writing
# EPOCH 39 Batch 15900 ...
# Validation loss = 0.154
# Validation Accuracy = 0.957
#
# Batch 16000 Train Loss: 0.003 Train Accuracy: 1.000
#
# valid writing
# EPOCH 40 Batch 16000 ...
# Validation loss = 0.154
# Validation Accuracy = 0.957
#
# Batch 16100 Train Loss: 0.012 Train Accuracy: 1.000
#
# valid writing
# EPOCH 40 Batch 16100 ...
# Validation loss = 0.139
# Validation Accuracy = 0.960
#
# Batch 16200 Train Loss: 0.004 Train Accuracy: 1.000
#
# valid writing
# EPOCH 40 Batch 16200 ...
# Validation loss = 0.138
# Validation Accuracy = 0.961
#
# Batch 16300 Train Loss: 0.014 Train Accuracy: 0.996
#
# valid writing
# EPOCH 40 Batch 16300 ...
# Validation loss = 0.149
# Validation Accuracy = 0.961
#
# Training Done

# %% [markdown]
# ## Evaluate the Model
# Once you are completely satisfied with your model, evaluate the performance of the model on the test set.
#
# Be sure to only do this once!
#
# If you were to measure the performance of your trained model on the test set, then improve your model, and then measure the performance of your model on the test set again, that would invalidate your test results. You wouldn't get a true measure of how well your model would perform against real data.
#
# You do not need to modify this section.

# %%
with tf.Session() as sess:
    saver.restore(sess, tf.train.latest_checkpoint(checkpoint_dir))

    train_loss, train_accuracy = evaluate(X_train, y_train)
    print("Train Loss = {:.3f}".format(train_loss))
    print("Train Accuracy = {:.3f}".format(train_accuracy))

with tf.Session() as sess:
    saver.restore(sess, tf.train.latest_checkpoint(checkpoint_dir))

    valid_loss, valid_accuracy = evaluate(X_valid, y_valid)
    print("Valid Loss = {:.3f}".format(valid_loss))
    print("Valid Accuracy = {:.3f}".format(valid_accuracy))

with tf.Session() as sess:
    saver.restore(sess, tf.train.latest_checkpoint(checkpoint_dir))

    test_loss, test_accuracy = evaluate(X_test, y_test)
    print("Test Loss = {:.3f}".format(test_loss))
    print("Test Accuracy = {:.3f}".format(test_accuracy))
# Out:
# Train Loss = 0.007
# Train Accuracy = 0.999
# Valid Loss = 0.149
# Valid Accuracy = 0.961
# Test Loss = 0.182
# Test Accuracy = 0.950
